# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# URL. It is 'https://understat.com/league' + '/name_of_the_league' + '/year_start_of_the_season'

# %%
# create urls for all seasons of all leagues
base_url = 'https://understat.com/league'
leagues = ['La_liga', 'EPL', 'Bundesliga', 'Serie_A', 'Ligue_1', 'RFPL']
seasons = ['2014', '2015', '2016', '2017', '2018','2019']

# %%
# Starting with latest data for Spanish league, because I'm a Barcelona fan
url = base_url+'/'+leagues[0]+'/'+seasons[4]
res = requests.get(url)
soup = BeautifulSoup(res.content, "lxml")

# Based on the structure of the webpage, I found that data is in the JSON variable, under <script> tags
scripts = soup.find_all('script')

# Check our <script> tags
# for el in scripts:
#   print('*'*50)
#   print(el.text)

# %%
import json

string_with_json_obj = ''

# Find data for teams
for el in scripts:
    if 'teamsData' in el.text:
      string_with_json_obj = el.text.strip()
      
# print(string_with_json_obj)

# strip unnecessary symbols and get only JSON data
ind_start = string_with_json_obj.index("('")+2
ind_end = string_with_json_obj.index("')")
json_data = string_with_json_obj[ind_start:ind_end]

json_data = json_data.encode('utf8').decode('unicode_escape')

# %%
# convert JSON data into Python dictionary
data = json.loads(json_data)
print(data.keys())
print('='*50)
print(data['138'].keys())
print('='*50)
print(data['138']['id'])
print('='*50)
print(data['138']['title'])
print('='*50)
print(data['138']['history'][0])
# Out:
# dict_keys(['138', '140', '141', '142', '143', '145', '146', '147', '148', '150', '151', '152', '153', '154', '156', '158', '159', '223', '231', '232'])
# ==================================================
# dict_keys(['id', 'title', 'history'])
# ==================================================
# 138
# ==================================================
# Sevilla
# ==================================================
# {'h_a': 'a', 'xG': 3.34997, 'xGA': 2.39239, 'npxG': 3.34997, 'npxGA': 1.64976, 'ppda': {'att': 252, 'def': 19}, 'ppda_allowed': {'att': 263, 'def': 20}, 'deep': 12, 'deep_allowed': 5, 'scored': 4, 'missed': 1, 'xpts': 1.9829999999999999, 'result': 'w', 'date': '2018-08-19 21:15:00', 'wins': 1, 'draws': 0, 'loses': 0, 'pts': 3, 'npxGD': 1.70021}

# %%
s = json.dumps(data, indent=4, sort_keys=True)
print(s)
# Out:
# {
#     "138": {
#         "history": [
#             {
#                 "date": "2018-08-19 21:15:00",
#                 "deep": 12,
#                 "deep_allowed": 5,
#                 "draws": 0,
#                 "h_a": "a",
#                 "loses": 0,
#                 "missed": 1,
#                 "npxG": 3.34997,
#                 "npxGA": 1.64976,
#                 "npxGD": 1.70021,
#                 "ppda": {
#                     "att": 252,
#                     "def": 19
#                 },
#                 "ppda_allowed": {
#                     "att": 263,
#                     "def": 20
#                 },
#                 "pts": 3,
#                 "result": "w",
#                 "scored": 4,
#                 "wins": 1,
#                 "xG": 3.34997,
#                 "xGA": 2.39239,
#                 "xpts": 1.9829999999999999
#             },
#             {
#                 "date": "2018-08-26 21:15:00",
#                 "deep": 11,
#                 "deep_allowed": 3,
#                 "draws": 1,
#                 "h_a": "h",
#                 "loses": 0,
#                 "missed": 0,
#                 "npxG": 1.97161,
#                 "npxGA": 0.671429,
#                 "npxGD": 1.300181,
#                 "ppda": {
#                     "att": 262,
#                     "def": 16
#                 },
#                 "ppda_allowed": {
#                     "att": 237,
#                     "def": 26
#                 },
#                 "pts": 1,
#                 "result": "d",
#                 "scored": 0,
#                 "wins": 0,
#                 "xG": 1.97161,
#                 "xGA": 0.671429,
#                 "xpts": 2.3331
#             },
#             {
#                 "date": "2018-09-02 18:45:00",
#                 "deep": 2,
#                 "deep_allowed": 5,
#                 "draws": 0,
#                 "h_a": "a",
#                 "loses": 1,
#                 "missed": 1,
#                 "npxG": 0.784969,
#                 "npxGA": 1.18295,
#                 "npxGD": -0.3979809999999999,
#                 "ppda": {
#                     "att": 303,
#                     "def": 25
#                 },
#                 "ppda_allowed": {
#                     "att": 149,
#                     "def": 21
#                 },
#                 "pts": 0,
#                 "result": "l",
#                 "scored": 0,
#                 "wins": 0,
#                 "xG": 0.784969,
#                 "xGA": 1.18295,
#                 "xpts": 0.9556
#             },
#             {
#                 "date": "2018-09-16 18:45:00",
#                 "deep": 20,
#                 "deep_allowed": 4,
#                 "draws": 0,
#                 "h_a": "h",
#                 "loses": 1,
#                 "missed": 2,
#                 "npxG": 1.08255,
#                 "npxGA": 2.12717,
#                 "npxGD": -1.04462,
#                 "ppda": {
#                     "att": 107,
#                     "def": 26
#                 },
#                 "ppda_allowed": {
#                     "att": 295,
#                     "def": 22
#                 },
#                 "pts": 0,
#                 "result": "l",
#                 "scored": 0,
#                 "wins": 0,
#                 "xG": 1.08255,
#                 "xGA": 2.12717,
#                 "xpts": 0.6337999999999999
#             },
#             {
#                 "date": "2018-09-23 10:00:00",
#                 "deep": 13,
#                 "deep_allowed": 9,
#                 "draws": 0,
#                 "h_a": "a",
#                 "loses": 0,
#                 "missed": 2,
#                 "npxG": 3.40128,
#                 "npxGA": 1.50532,
#                 "npxGD": 1.8959599999999999,
#                 "ppda": {
#                     "att": 235,
#                     "def": 23
#                 },
#                 "ppda_allowed": {
#                     "att": 267,
#                     "def": 15
#                 },
#                 "pts": 3,
#                 "result": "w",
#                 "scored": 6,
#                 "wins": 1,
#                 "xG": 3.40128,
#                 "xGA": 2.24847,
#                 "xpts": 2.1285
#             },
#             {
#                 "date": "2018-09-26 20:00:00",
#                 "deep": 7,
#                 "deep_allowed": 10,
#                 "draws": 0,
#                 "h_a": "h",
#                 "loses": 0,
#                 "missed": 0,
#                 "npxG": 2.29262,
#                 "npxGA": 1.55351,
#                 "npxGD": 0.7391099999999999,
#                 "ppda": {
#                     "att": 300,
#                     "def": 17
#                 },
#                 "ppda_allowed": {
#                     "att": 209,
#                     "def": 17
#                 },
#                 "pts": 3,
#                 "result": "w",
#                 "scored": 3,
#                 "wins": 1,
#                 "xG": 2.29262,
#                 "xGA": 1.55351,
#                 "xpts": 1.9024
#             },
#             {
#                 "date": "2018-09-29 16:30:00",
#                 "deep": 2,
#                 "deep_allowed": 2,
#                 "draws": 0,
#                 "h_a": "a",
#                 "loses": 0,
#                 "missed": 1,
#                 "npxG": 1.24204,
#                 "npxGA": 0.563865,
#                 "npxGD": 0.6781750000000001,
#                 "ppda": {
#                     "att": 263,
#                     "def": 11
#                 },
#                 "ppda_allowed": {
#                     "att": 159,
#                     "def": 34
#                 },
#                 "pts": 3,
#                 "result": "w",
#                 "scored": 3,
#                 "wins": 1,
#                 "xG": 1.98532,
#                 "xGA": 0.563865,
#                 "xpts": 2.5246
#             },
#             {
#                 "date": "2018-10-07 16:30:00",
#                 "deep": 8,
#                 "deep_allowed": 9,
#                 "draws": 0,
#                 "h_a": "h",
#                 "loses": 0,
#                 "missed": 1,
#                 "npxG": 2.237,
#                 "npxGA": 0.895831,
#                 "npxGD": 1.341169,
#                 "ppda": {
#                     "att": 242,
#                     "def": 22
#                 },
#                 "ppda_allowed": {
#                     "att": 257,
#                     "def": 21
#                 },
#                 "pts": 3,
#                 "result": "w",
#                 "scored": 2,
#                 "wins": 1,
#                 "xG": 2.237,
#                 "xGA": 0.895831,
#                 "xpts": 2.3711
#             },
#             {
#                 "date": "2018-10-20 18:45:00",
#                 "deep": 8,
#                 "deep_allowed": 8,
#                 "draws": 0,
#                 "h_a": "a",
#                 "loses": 1,
#                 "missed": 4,
#                 "npxG": 1.89801,
#                 "npxGA": 2.4762,
#                 "npxGD": -0.57819,
#                 "ppda": {
#                     "att": 289,
#                     "def": 28
#                 },
#                 "ppda_allowed": {
#                     "att": 225,
#                     "def": 21
#                 },
#                 "pts": 0,
#                 "result": "l",
#                 "scored": 2,
#                 "wins": 0,
#                 "xG": 1.89801,
#                 "xGA": 3.21948,
#                 "xpts": 0.6312
#             },
#             {
#                 "date": "2018-10-28 18:45:00",
#                 "deep": 9,
#                 "deep_allowed": 5,
#                 "draws": 0,
#                 "h_a": "h",
#                 "loses": 0,
#                 "missed": 1,
#                 "npxG": 1.88431,
#                 "npxGA": 1.01306,
#                 "npxGD": 0.8712499999999999,
#                 "ppda": {
#                     "att": 191,
#                     "def": 16
#                 },
#                 "ppda_allowed": {
#                     "att": 327,
#                     "def": 18
#                 },
#                 "pts": 3,
#                 "result": "w",
#                 "scored": 2,
#                 "wins": 1,
#                 "xG": 1.88431,
#                 "xGA": 1.01306,
#                 "xpts": 2.0721
#             },
#             {
#                 "date": "2018-11-04 17:30:00",
#                 "deep": 2,
#                 "deep_allowed": 6,
#                 "draws": 1,
#                 "h_a": "a",
#                 "loses": 0,
#                 "missed": 0,
#                 "npxG": 0.413773,
#                 "npxGA": 0.74078,
#                 "npxGD": -0.327007,
#                 "ppda": {
#                     "att": 274,
#                     "def": 28
#                 },
#                 "ppda_allowed": {
#                     "att": 236,
#                     "def": 23
#                 },
#                 "pts": 1,
#                 "result": "d",
#                 "scored": 0,
#                 "wins": 0,
#                 "xG": 0.413773,
#                 "xGA": 0.74078,
#                 "xpts": 0.9386000000000001
#             },
#             {
#                 "date": "2018-11-11 17:30:00",
#                 "deep": 12,
#                 "deep_allowed": 4,
#                 "draws": 0,
#                 "h_a": "h",
#                 "loses": 0,
#                 "missed": 1,
#                 "npxG": 3.95375,
#                 "npxGA": 0.686451,
#                 "npxGD": 3.267299,
#                 "ppda": {
#                     "att": 270,
#                     "def": 29
#                 },
#                 "ppda_allowed": {
#                     "att": 205,
#                     "def": 25
#                 },
#                 "pts": 3,
#                 "result": "w",
#                 "scored": 2,
#                 "wins": 1,
#                 "xG": 3.95375,
#                 "xGA": 0.686451,
#                 "xpts": 2.8896
#             },
#             {
#                 "date": "2018-11-25 15:15:00",
#                 "deep": 10,
#                 "deep_allowed": 1,
#                 "draws": 0,
#                 "h_a": "h",
#                 "loses": 0,
#                 "missed": 0,
#                 "npxG": 1.40358,
#                 "npxGA": 0.53321,
#                 "npxGD": 0.8703700000000001,
#                 "ppda": {
#                     "att": 262,
#                     "def": 22
#                 },
#                 "ppda_allowed": {
#                     "att": 248,
#                     "def": 27
#                 },
#                 "pts": 3,
#                 "result": "w",
#                 "scored": 1,
#                 "wins": 1,
#                 "xG": 1.40358,
#                 "xGA": 0.53321,
#                 "xpts": 2.1301
#             },
#             {
#                 "date": "2018-12-02 19:45:00",
#                 "deep": 13,
#                 "deep_allowed": 4,
#                 "draws": 1,
#                 "h_a": "a",
#                 "loses": 0,
#                 "missed": 1,
#                 "npxG": 1.64539,
#                 "npxGA": 1.0211,
#                 "npxGD": 0.62429,
#                 "ppda": {
#                     "att": 182,
#                     "def": 25
#                 },
#                 "ppda_allowed": {
#                     "att": 238,
#                     "def": 38
#                 },
#                 "pts": 1,
#                 "result": "d",
#                 "scored": 1,
#                 "wins": 0,
#                 "xG": 1.64539,
#                 "xGA": 1.0211,
#                 "xpts": 1.8640000000000003
#             },
#             {
#                 "date": "2018-12-08 15:15:00",
#                 "deep": 6,
#                 "deep_allowed": 14,
#                 "draws": 1,
#                 "h_a": "a",
#                 "loses": 0,
#                 "missed": 1,
#                 "npxG": 1.64731,
#                 "npxGA": 1.44342,
#                 "npxGD": 0.20389000000000013,
#                 "ppda": {
#                     "att": 230,
#                     "def": 17
#                 },
#                 "ppda_allowed": {
#                     "att": 222,
#                     "def": 29
#                 },
#                 "pts": 1,
#                 "result": "d",
#                 "scored": 1,
#                 "wins": 0,
#                 "xG": 1.64731,
#                 "xGA": 1.44342,
#                 "xpts": 1.5406
#             },
#             {
#                 "date": "2018-12-16 11:00:00",
#                 "deep": 20,
#                 "deep_allowed": 9,
#                 "draws": 0,
#                 "h_a": "h",
#                 "loses": 0,
#                 "missed": 0,
#                 "npxG": 1.53867,
#                 "npxGA": 0.811788,
#                 "npxGD": 0.726882,
#                 "ppda": {
#                     "att": 247,
#                     "def": 23
#                 },
#                 "ppda_allowed": {
#                     "att": 230,
#                     "def": 26
#                 },
#                 "pts": 3,
#                 "result": "w",
#                 "scored": 2,
#                 "wins": 1,
#                 "xG": 2.28195,
#                 "xGA": 0.811788,
#                 "xpts": 2.4462
#             },
#             {
#                 "date": "2018-12-23 15:15:00",
#                 "deep": 3,
#                 "deep_allowed": 9,
#                 "draws": 1,
#                 "h_a": "a",
#                 "loses": 0,
#                 "missed": 1,
#                 "npxG": 0.697523,
#                 "npxGA": 1.13295,
#                 "npxGD": -0.4354269999999999,
#                 "ppda": {
#                     "att": 211,
#                     "def": 19
#                 },
#                 "ppda_allowed": {
#                     "att": 250,
#                     "def": 21
#                 },
#                 "pts": 1,
#                 "result": "d",
#                 "scored": 1,
#                 "wins": 0,
#                 "xG": 0.697523,
#                 "xGA": 1.13295,
#                 "xpts": 0.9097000000000001
#             },
#             {
#                 "date": "2019-01-06 15:15:00",
#                 "deep": 8,
#                 "deep_allowed": 2,
#                 "draws": 1,
#                 "h_a": "h",
#                 "loses": 0,
#                 "missed": 1,
#                 "npxG": 1.57396,
#                 "npxGA": 0.758265,
#                 "npxGD": 0.8156950000000001,
#                 "ppda": {
#                     "att": 188,
#                     "def": 26
#                 },
#                 "ppda_allowed": {
#                     "att": 258,
#                     "def": 33
#                 },
#                 "pts": 1,
#                 "result": "d",
#                 "scored": 1,
#                 "wins": 0,
#                 "xG": 1.57396,
#                 "xGA": 0.758265,
#                 "xpts": 2.0331
#             },
#             {
#                 "date": "2019-01-13 15:15:00",
#                 "deep": 7,
#                 "deep_allowed": 6,
#                 "draws": 0,
#                 "h_a": "a",
#                 "loses": 1,
#                 "missed": 2,
#                 "npxG": 0.735092,
#                 "npxGA": 1.20272,
#                 "npxGD": -0.46762800000000004,
#                 "ppda": {
#                     "att": 184,
#                     "def": 21
#                 },
#                 "ppda_allowed": {
#                     "att": 247,
#                     "def": 24
#                 },
#                 "pts": 0,
#                 "result": "l",
#                 "scored": 0,
#                 "wins": 0,
#                 "xG": 0.735092,
#                 "xGA": 1.20272,
#                 "xpts": 0.8966000000000001
#             },
#             {
#                 "date": "2019-01-19 15:15:00",
#                 "deep": 1,
#                 "deep_allowed": 11,
#                 "draws": 0,
#                 "h_a": "a",
#                 "loses": 1,
#                 "missed": 2,
#                 "npxG": 0.396637,
#                 "npxGA": 1.59927,
#                 "npxGD": -1.202633,
#                 "ppda": {
#                     "att": 291,
#                     "def": 23
#                 },
#                 "ppda_allowed": {
#                     "att": 164,
#                     "def": 30
#                 },
#                 "pts": 0,
#                 "result": "l",
#                 "scored": 0,
#                 "wins": 0,
#                 "xG": 0.396637,
#                 "xGA": 1.59927,
#                 "xpts": 0.4489
#             },
#             {
#                 "date": "2019-01-26 12:00:00",
#                 "deep": 13,
#                 "deep_allowed": 5,
#                 "draws": 0,
#                 "h_a": "h",
#                 "loses": 0,
#                 "missed": 0,
#                 "npxG": 3.38449,
#                 "npxGA": 0.299152,
#                 "npxGD": 3.085338,
#                 "ppda": {
#                     "att": 185,
#                     "def": 25
#                 },
#                 "ppda_allowed": {
#                     "att": 224,
#                     "def": 27
#                 },
#                 "pts": 3,
#                 "result": "w",
#                 "scored": 5,
#                 "wins": 1,
#                 "xG": 5.03124,
#                 "xGA": 0.299152,
#                 "xpts": 2.9943
#             },
#             {
#                 "date": "2019-02-02 19:45:00",
#                 "deep": 9,
#                 "deep_allowed": 5,
#                 "draws": 0,
#                 "h_a": "a",
#                 "loses": 1,
#                 "missed": 1,
#                 "npxG": 0.682747,
#                 "npxGA": 0.935214,
#                 "npxGD": -0.252467,
#                 "ppda": {
#                     "att": 266,
#                     "def": 23
#                 },
#                 "ppda_allowed": {
#                     "att": 339,
#                     "def": 27
#                 },
#                 "pts": 0,
#                 "result": "l",
#                 "scored": 0,
#                 "wins": 0,
#                 "xG": 0.682747,
#                 "xGA": 0.935214,
#                 "xpts": 1.0488
#             },
#             {
#                 "date": "2019-02-10 17:30:00",
#                 "deep": 13,
#                 "deep_allowed": 7,
#                 "draws": 1,
#                 "h_a": "h",
#                 "loses": 0,
#                 "missed": 2,
#                 "npxG": 1.54912,
#                 "npxGA": 1.43993,
#                 "npxGD": 0.10919000000000012,
#                 "ppda": {
#                     "att": 138,
#                     "def": 12
#                 },
#                 "ppda_allowed": {
#                     "att": 252,
#                     "def": 25
#                 },
#                 "pts": 1,
#                 "result": "d",
#                 "scored": 2,
#                 "wins": 0,
#                 "xG": 1.54912,
#                 "xGA": 1.43993,
#                 "xpts": 1.4426999999999999
#             },
#             {
#                 "date": "2019-02-17 17:30:00",
#                 "deep": 12,
#                 "deep_allowed": 4,
#                 "draws": 0,
#                 "h_a": "a",
#                 "loses": 1,
#                 "missed": 3,
#                 "npxG": 2.49386,
#                 "npxGA": 1.85386,
#                 "npxGD": 0.6400000000000001,
#                 "ppda": {
#                     "att": 198,
#                     "def": 21
#                 },
#                 "ppda_allowed": {
#                     "att": 276,
#                     "def": 20
#                 },
#                 "pts": 0,
#                 "result": "l",
#                 "scored": 0,
#                 "wins": 0,
#                 "xG": 2.49386,
#                 "xGA": 1.85386,
#                 "xpts": 1.7715999999999998
#             },
#             {
#                 "date": "2019-02-23 15:15:00",
#                 "deep": 6,
#                 "deep_allowed": 5,
#                 "draws": 0,
#                 "h_a": "h",
#                 "loses": 1,
#                 "missed": 4,
#                 "npxG": 1.64536,
#                 "npxGA": 1.7385,
#                 "npxGD": -0.09314,
#                 "ppda": {
#                     "att": 310,
#                     "def": 20
#                 },
#                 "ppda_allowed": {
#                     "att": 162,
#                     "def": 12
#                 },
#                 "pts": 0,
#                 "result": "l",
#                 "scored": 2,
#                 "wins": 0,
#                 "xG": 1.64536,
#                 "xGA": 1.7385,
#                 "xpts": 1.3347000000000002
#             },
#             {
#                 "date": "2019-03-02 17:30:00",
#                 "deep": 10,
#                 "deep_allowed": 4,
#                 "draws": 0,
#                 "h_a": "a",
#                 "loses": 1,
#                 "missed": 2,
#                 "npxG": 1.78648,
#                 "npxGA": 0.940056,
#                 "npxGD": 0.8464240000000001,
#                 "ppda": {
#                     "att": 84,
#                     "def": 31
#                 },
#                 "ppda_allowed": {
#                     "att": 338,
#                     "def": 28
#                 },
#                 "pts": 0,
#                 "result": "l",
#                 "scored": 1,
#                 "wins": 0,
#                 "xG": 2.52975,
#                 "xGA": 0.940056,
#                 "xpts": 2.5727
#             },
#             {
#                 "date": "2019-03-10 17:30:00",
#                 "deep": 14,
#                 "deep_allowed": 0,
#                 "draws": 0,
#                 "h_a": "h",
#                 "loses": 0,
#                 "missed": 2,
#                 "npxG": 2.88735,
#                 "npxGA": 0.489883,
#                 "npxGD": 2.3974670000000002,
#                 "ppda": {
#                     "att": 272,
#                     "def": 24
#                 },
#                 "ppda_allowed": {
#                     "att": 195,
#                     "def": 26
#                 },
#                 "pts": 3,
#                 "result": "w",
#                 "scored": 5,
#                 "wins": 1,
#                 "xG": 2.88735,
#                 "xGA": 1.23303,
#                 "xpts": 2.4615
#             },
#             {
#                 "date": "2019-03-17 15:15:00",
#                 "deep": 4,
#                 "deep_allowed": 5,
#                 "draws": 0,
#                 "h_a": "a",
#                 "loses": 0,
#                 "missed": 0,
#                 "npxG": 0.598647,
#                 "npxGA": 0.665136,
#                 "npxGD": -0.06648899999999991,
#                 "ppda": {
#                     "att": 234,
#                     "def": 24
#                 },
#                 "ppda_allowed": {
#                     "att": 259,
#                     "def": 32
#                 },
#                 "pts": 3,
#                 "result": "w",
#                 "scored": 1,
#                 "wins": 1,
#                 "xG": 1.34192,
#                 "xGA": 0.665136,
#                 "xpts": 1.9969
#             },
#             {
#                 "date": "2019-03-31 14:15:00",
#                 "deep": 10,
#                 "deep_allowed": 3,
#                 "draws": 0,
#                 "h_a": "h",
#                 "loses": 1,
#                 "missed": 1,
#                 "npxG": 0.745225,
#                 "npxGA": 0.179921,
#                 "npxGD": 0.565304,
#                 "ppda": {
#                     "att": 187,
#                     "def": 20
#                 },
#                 "ppda_allowed": {
#                     "att": 282,
#                     "def": 26
#                 },
#                 "pts": 0,
#                 "result": "l",
#                 "scored": 0,
#                 "wins": 0,
#                 "xG": 0.745225,
#                 "xGA": 0.923071,
#                 "xpts": 1.0499
#             },
#             {
#                 "date": "2019-04-04 18:30:00",
#                 "deep": 11,
#                 "deep_allowed": 1,
#                 "draws": 0,
#                 "h_a": "h",
#                 "loses": 0,
#                 "missed": 0,
#                 "npxG": 2.02786,
#                 "npxGA": 0.590085,
#                 "npxGD": 1.437775,
#                 "ppda": {
#                     "att": 157,
#                     "def": 24
#                 },
#                 "ppda_allowed": {
#                     "att": 287,
#                     "def": 25
#                 },
#                 "pts": 3,
#                 "result": "w",
#                 "scored": 2,
#                 "wins": 1,
#                 "xG": 2.02786,
#                 "xGA": 0.590085,
#                 "xpts": 2.4488000000000003
#             },
#             {
#                 "date": "2019-04-07 15:15:00",
#                 "deep": 5,
#                 "deep_allowed": 4,
#                 "draws": 0,
#                 "h_a": "a",
#                 "loses": 0,
#                 "missed": 0,
#                 "npxG": 2.24314,
#                 "npxGA": 1.33089,
#                 "npxGD": 0.91225,
#                 "ppda": {
#                     "att": 188,
#                     "def": 24
#                 },
#                 "ppda_allowed": {
#                     "att": 290,
#                     "def": 26
#                 },
#                 "pts": 3,
#                 "result": "w",
#                 "scored": 2,
#                 "wins": 1,
#                 "xG": 2.24314,
#                 "xGA": 1.33089,
#                 "xpts": 2.0909
#             },
#             {
#                 "date": "2019-04-13 19:45:00",
#                 "deep": 8,
#                 "deep_allowed": 6,
#                 "draws": 0,
#                 "h_a": "h",
#                 "loses": 0,
#                 "missed": 2,
#                 "npxG": 2.32083,
#                 "npxGA": 1.09294,
#                 "npxGD": 1.22789,
#                 "ppda": {
#                     "att": 309,
#                     "def": 22
#                 },
#                 "ppda_allowed": {
#                     "att": 152,
#                     "def": 20
#                 },
#                 "pts": 3,
#                 "result": "w",
#                 "scored": 3,
#                 "wins": 1,
#                 "xG": 2.32083,
#                 "xGA": 1.09294,
#                 "xpts": 2.3320000000000003
#             },
#             {
#                 "date": "2019-04-21 13:00:00",
#                 "deep": 1,
#                 "deep_allowed": 5,
#                 "draws": 0,
#                 "h_a": "a",
#                 "loses": 1,
#                 "missed": 3,
#                 "npxG": 0.625236,
#                 "npxGA": 1.24048,
#                 "npxGD": -0.615244,
#                 "ppda": {
#                     "att": 122,
#                     "def": 16
#                 },
#                 "ppda_allowed": {
#                     "att": 246,
#                     "def": 31
#                 },
#                 "pts": 0,
#                 "result": "l",
#                 "scored": 0,
#                 "wins": 0,
#                 "xG": 0.625236,
#                 "xGA": 2.72704,
#                 "xpts": 0.13090000000000002
#             },
#             {
#                 "date": "2019-04-25 18:30:00",
#                 "deep": 10,
#                 "deep_allowed": 3,
#                 "draws": 0,
#                 "h_a": "h",
#                 "loses": 0,
#                 "missed": 0,
#                 "npxG": 3.63403,
#                 "npxGA": 0.75592,
#                 "npxGD": 2.87811,
#                 "ppda": {
#                     "att": 247,
#                     "def": 21
#                 },
#                 "ppda_allowed": {
#                     "att": 181,
#                     "def": 31
#                 },
#                 "pts": 3,
#                 "result": "w",
#                 "scored": 5,
#                 "wins": 1,
#                 "xG": 3.63403,
#                 "xGA": 0.75592,
#                 "xpts": 2.8733
#             },
#             {
#                 "date": "2019-04-28 13:00:00",
#                 "deep": 5,
#                 "deep_allowed": 9,
#                 "draws": 0,
#                 "h_a": "a",
#                 "loses": 1,
#                 "missed": 1,
#                 "npxG": 1.06533,
#                 "npxGA": 1.02214,
#                 "npxGD": 0.04319000000000006,
#                 "ppda": {
#                     "att": 202,
#                     "def": 34
#                 },
#                 "ppda_allowed": {
#                     "att": 284,
#                     "def": 32
#                 },
#                 "pts": 0,
#                 "result": "l",
#                 "scored": 0,
#                 "wins": 0,
#                 "xG": 1.06533,
#                 "xGA": 1.02214,
#                 "xpts": 1.4156
#             },
#             {
#                 "date": "2019-05-03 20:00:00",
#                 "deep": 6,
#                 "deep_allowed": 6,
#                 "draws": 0,
#                 "h_a": "h",
#                 "loses": 1,
#                 "missed": 3,
#                 "npxG": 0.298434,
#                 "npxGA": 1.28827,
#                 "npxGD": -0.989836,
#                 "ppda": {
#                     "att": 127,
#                     "def": 25
#                 },
#                 "ppda_allowed": {
#                     "att": 254,
#                     "def": 41
#                 },
#                 "pts": 0,
#                 "result": "l",
#                 "scored": 0,
#                 "wins": 0,
#                 "xG": 0.298434,
#                 "xGA": 1.28827,
#                 "xpts": 0.4503
#             },
#             {
#                 "date": "2019-05-12 17:30:00",
#                 "deep": 4,
#                 "deep_allowed": 6,
#                 "draws": 1,
#                 "h_a": "a",
#                 "loses": 0,
#                 "missed": 1,
#                 "npxG": 0.65825,
#                 "npxGA": 1.4302,
#                 "npxGD": -0.7719499999999999,
#                 "ppda": {
#                     "att": 255,
#                     "def": 22
#                 },
#                 "ppda_allowed": {
#                     "att": 275,
#                     "def": 23
#                 },
#                 "pts": 1,
#                 "result": "d",
#                 "scored": 1,
#                 "wins": 0,
#                 "xG": 0.65825,
#                 "xGA": 1.4302,
#                 "xpts": 0.6607000000000001
#             },
#             {
#                 "date": "2019-05-18 14:15:00",
#                 "deep": 6,
#                 "deep_allowed": 7,
#                 "draws": 0,
#                 "h_a": "h",
#                 "loses": 0,
#                 "missed": 0,
#                 "npxG": 1.74602,
#                 "npxGA": 0.647189,
#                 "npxGD": 1.098831,
#                 "ppda": {
#                     "att": 227,
#                     "def": 18
#                 },
#                 "ppda_allowed": {
#                     "att": 186,
#                     "def": 22
#                 },
#                 "pts": 3,
#                 "result": "w",
#                 "scored": 2,
#                 "wins": 1,
#                 "xG": 1.74602,
#                 "xGA": 0.647189,
#                 "xpts": 2.3697
#             }
#         ],
#         "id": "138",
#         "title": "Sevilla"
#     },
#     "140": {
#         "history": [
#             {
#                 "date": "2018-08-18 21:15:00",
#                 "deep": 3,
#                 "deep_allowed": 8,
#                 "draws": 0,
#                 "h_a": "a",
#                 "loses": 0,
#                 "missed": 1,
#                 "npxG": 0.410646,
#                 "npxGA": 1.39716,
#                 "npxGD": -0.9865139999999999,
#                 "ppda": {
#                     "att": 212,
#                     "def": 19
#                 },
#                 "ppda_allowed": {
#                     "att": 256,
#                     "def": 28
#                 },
#                 "pts": 3,
#                 "result": "w",
#                 "scored": 2,
#                 "wins": 1,
#                 "xG": 0.410646,
#                 "xGA": 1.39716,
#                 "xpts": 0.5298
#             },
#             {
#                 "date": "2018-08-24 23:15:00",
#                 "deep": 3,
#                 "deep_allowed": 11,
#                 "draws": 1,
#                 "h_a": "a",
#                 "loses": 0,
#                 "missed": 2,
#                 "npxG": 1.69572,
#                 "npxGA": 1.67636,
#                 "npxGD": 0.019359999999999822,
#                 "ppda": {
#                     "att": 353,
#                     "def": 17
#                 },
#                 "ppda_allowed": {
#                     "att": 134,
#                     "def": 21
#                 },
#                 "pts": 1,
#                 "result": "d",
#                 "scored": 2,
#                 "wins": 0,
#                 "xG": 1.69572,
#                 "xGA": 1.67636,
#                 "xpts": 1.4312
#             },
#             {
#                 "date": "2018-08-31 23:00:00",
#                 "deep": 1,
#                 "deep_allowed": 8,
#                 "draws": 0,
#                 "h_a": "a",
#                 "loses": 1,
#                 "missed": 2,
#                 "npxG": 0.5806,
#                 "npxGA": 0.798059,
#                 "npxGD": -0.21745899999999996,
#                 "ppda": {
#                     "att": 151,
#                     "def": 20
#                 },
#                 "ppda_allowed": {
#                     "att": 148,
#                     "def": 31
#                 },
#                 "pts": 0,
#                 "result": "l",
#                 "scored": 1,
#                 "wins": 0,
#                 "xG": 1.32388,
#                 "xGA": 0.798059,
#                 "xpts": 1.8908000000000003
#             },
#             {
#                 "date": "2018-09-15 14:15:00",
#                 "deep": 3,
#                 "deep_allowed": 9,
#                 "draws": 0,
#                 "h_a": "h",
#                 "loses": 1,
#                 "missed": 2,
#                 "npxG": 1.47969,
#                 "npxGA": 1.7617,
#                 "npxGD": -0.2820100000000001,
#                 "ppda": {
#                     "att": 432,
#                     "def": 36
#                 },
#                 "ppda_allowed": {
#                     "att": 218,
#                     "def": 22
#                 },
#                 "pts": 0,
#                 "result": "l",
#                 "scored": 1,
#                 "wins": 0,
#                 "xG": 1.47969,
#                 "xGA": 1.7617,
#                 "xpts": 1.1398000000000001
#             },
#             {
#                 "date": "2018-09-21 19:00:00",
#                 "deep": 4,
#                 "deep_allowed": 3,
#                 "draws": 0,
#                 "h_a": "a",
#                 "loses": 0,
#                 "missed": 0,
#                 "npxG": 0.200875,
#                 "npxGA": 0.565773,
#                 "npxGD": -0.36489799999999994,
#                 "ppda": {
#                     "att": 194,
#                     "def": 22
#                 },
#                 "ppda_allowed": {
#                     "att": 242,
#                     "def": 20
#                 },
#                 "pts": 3,
#                 "result": "w",
#                 "scored": 1,
#                 "wins": 1,
#                 "xG": 0.200875,
#                 "xGA": 0.565773,
#                 "xpts": 0.8349
#             },
#             {
#                 "date": "2018-09-25 19:00:00",
#                 "deep": 11,
#                 "deep_allowed": 5,
#                 "draws": 1,
#                 "h_a": "h",
#                 "loses": 0,
#                 "missed": 2,
#                 "npxG": 1.23911,
#                 "npxGA": 1.03675,
#                 "npxGD": 0.20235999999999987,
#                 "ppda": {
#                     "att": 189,
#                     "def": 36
#                 },
#                 "ppda_allowed": {
#                     "att": 290,
#                     "def": 23
#                 },
#                 "pts": 1,
#                 "result": "d",
#                 "scored": 2,
#                 "wins": 0,
#                 "xG": 1.23911,
#                 "xGA": 1.77977,
#                 "xpts": 0.9078
#             },
#             {
#                 "date": "2018-09-29 11:00:00",
#                 "deep": 4,
#                 "deep_allowed": 7,
#                 "draws": 0,
#                 "h_a": "h",
#                 "loses": 1,
#                 "missed": 1,
#                 "npxG": 0.377694,
#                 "npxGA": 0.924746,
#                 "npxGD": -0.547052,
#                 "ppda": {
#                     "att": 233,
#                     "def": 24
#                 },
#                 "ppda_allowed": {
#                     "att": 303,
#                     "def": 27
#                 },
#                 "pts": 0,
#                 "result": "l",
#                 "scored": 0,
#                 "wins": 0,
#                 "xG": 1.12097,
#                 "xGA": 0.924746,
#                 "xpts": 1.5417
#             },
#             {
#                 "date": "2018-10-05 19:00:00",
#                 "deep": 1,
#                 "deep_allowed": 8,
#                 "draws": 0,
#                 "h_a": "a",
#                 "loses": 0,
#                 "missed": 1,
#                 "npxG": 0.628384,
#                 "npxGA": 1.18842,
#                 "npxGD": -0.560036,
#                 "ppda": {
#                     "att": 287,
#                     "def": 24
#                 },
#                 "ppda_allowed": {
#                     "att": 132,
#                     "def": 23
#                 },
#                 "pts": 3,
#                 "result": "w",
#                 "scored": 3,
#                 "wins": 1,
#                 "xG": 2.11494,
#                 "xGA": 1.18842,
#                 "xpts": 2.1776000000000004
#             },
#             {
#                 "date": "2018-10-22 19:00:00",
#                 "deep": 6,
#                 "deep_allowed": 6,
#                 "draws": 1,
#                 "h_a": "h",
#                 "loses": 0,
#                 "missed": 0,
#                 "npxG": 0.57678,
#                 "npxGA": 0.53783,
#                 "npxGD": 0.03894999999999993,
#                 "ppda": {
#                     "att": 198,
#                     "def": 25
#                 },
#                 "ppda_allowed": {
#                     "att": 263,
#                     "def": 27
#                 },
#                 "pts": 1,
#                 "result": "d",
#                 "scored": 0,
#                 "wins": 0,
#                 "xG": 0.57678,
#                 "xGA": 0.53783,
#                 "xpts": 1.3317999999999999
#             },
#             {
#                 "date": "2018-10-27 18:45:00",
#                 "deep": 2,
#                 "deep_allowed": 10,
#                 "draws": 0,
#                 "h_a": "a",
#                 "loses": 1,
#                 "missed": 2,
#                 "npxG": 0.211158,
#                 "npxGA": 1.41243,
#                 "npxGD": -1.2012720000000001,
#                 "ppda": {
#                     "att": 283,
#                     "def": 14
#                 },
#                 "ppda_allowed": {
#                     "att": 209,
#                     "def": 35
#                 },
#                 "pts": 0,
#                 "result": "l",
#                 "scored": 0,
#                 "wins": 0,
#                 "xG": 0.211158,
#                 "xGA": 1.41243,
#                 "xpts": 0.3608
#             },
#             {
#                 "date": "2018-11-04 17:30:00",
#                 "deep": 6,
#                 "deep_allowed": 2,
#                 "draws": 1,
#                 "h_a": "h",
#                 "loses": 0,
#                 "missed": 0,
#                 "npxG": 0.74078,
#                 "npxGA": 0.413773,
#                 "npxGD": 0.327007,
#                 "ppda": {
#                     "att": 236,
#                     "def": 23
#                 },
#                 "ppda_allowed": {
#                     "att": 274,
#                     "def": 28
#                 },
#                 "pts": 1,
#                 "result": "d",
#                 "scored": 0,
#                 "wins": 0,
#                 "xG": 0.74078,
#                 "xGA": 0.413773,
#                 "xpts": 1.6505
#             },
#             {
#                 "date": "2018-11-09 20:00:00",
#                 "deep": 9,
#                 "deep_allowed": 6,
#                 "draws": 0,
#                 "h_a": "a",
#                 "loses": 0,
#                 "missed": 1,
#                 "npxG": 1.43351,
#                 "npxGA": 1.06813,
#                 "npxGD": 0.36538000000000004,
#                 "ppda": {
#                     "att": 176,
#                     "def": 18
#                 },
#                 "ppda_allowed": {
#                     "att": 225,
#                     "def": 35
#                 },
#                 "pts": 3,
#                 "result": "w",
#                 "scored": 3,
#                 "wins": 1,
#                 "xG": 1.43351,
#                 "xGA": 1.06813,
#                 "xpts": 1.6896000000000002
#             },
#             {
#                 "date": "2018-11-26 20:00:00",
#                 "deep": 9,
#                 "deep_allowed": 0,
#                 "draws": 0,
#                 "h_a": "h",
#                 "loses": 0,
#                 "missed": 1,
#                 "npxG": 2.07409,
#                 "npxGA": 0.545872,
#                 "npxGD": 1.5282179999999999,
#                 "ppda": {
#                     "att": 303,
#                     "def": 24
#                 },
#                 "ppda_allowed": {
#                     "att": 279,
#                     "def": 21
#                 },
#                 "pts": 3,
#                 "result": "w",
#                 "scored": 2,
#                 "wins": 1,
#                 "xG": 2.07409,
#                 "xGA": 0.545872,
#                 "xpts": 2.4944
#             },
#             {
#                 "date": "2018-12-02 11:00:00",
#                 "deep": 8,
#                 "deep_allowed": 4,
#                 "draws": 0,
#                 "h_a": "a",
#                 "loses": 1,
#                 "missed": 1,
#                 "npxG": 1.39194,
#                 "npxGA": 1.31385,
#                 "npxGD": 0.07808999999999999,
#                 "ppda": {
#                     "att": 293,
#                     "def": 26
#                 },
#                 "ppda_allowed": {
#                     "att": 232,
#                     "def": 33
#                 },
#                 "pts": 0,
#                 "result": "l",
#                 "scored": 0,
#                 "wins": 0,
#                 "xG": 1.39194,
#                 "xGA": 1.31385,
#                 "xpts": 1.3881999999999999
#             },
#             {
#                 "date": "2018-12-09 17:30:00",
#                 "deep": 9,
#                 "deep_allowed": 1,
#                 "draws": 0,
#                 "h_a": "h",
#                 "loses": 1,
#                 "missed": 2,
#                 "npxG": 1.7451,
#                 "npxGA": 1.31256,
#                 "npxGD": 0.43254000000000015,
#                 "ppda": {
#                     "att": 114,
#                     "def": 18
#                 },
#                 "ppda_allowed": {
#                     "att": 325,
#                     "def": 27
#                 },
#                 "pts": 0,
#                 "result": "l",
#                 "scored": 1,
#                 "wins": 0,
#                 "xG": 1.7451,
#                 "xGA": 1.31256,
#                 "xpts": 1.6883000000000001
#             },
#             {
#                 "date": "2018-12-15 12:00:00",
#                 "deep": 7,
#                 "deep_allowed": 2,
#                 "draws": 0,
#                 "h_a": "a",
#                 "loses": 1,
#                 "missed": 1,
#                 "npxG": 0.608285,
#                 "npxGA": 0.358274,
#                 "npxGD": 0.250011,
#                 "ppda": {
#                     "att": 80,
#                     "def": 23
#                 },
#                 "ppda_allowed": {
#                     "att": 376,
#                     "def": 42
#                 },
#                 "pts": 0,
#                 "result": "l",
#                 "scored": 0,
#                 "wins": 0,
#                 "xG": 0.608285,
#                 "xGA": 0.358274,
#                 "xpts": 1.5611000000000002
#             },
#             {
#                 "date": "2018-12-21 20:00:00",
#                 "deep": 6,
#                 "deep_allowed": 1,
#                 "draws": 0,
#                 "h_a": "h",
#                 "loses": 1,
#                 "missed": 1,
#                 "npxG": 1.06219,
#                 "npxGA": 0.877996,
#                 "npxGD": 0.18419399999999997,
#                 "ppda": {
#                     "att": 125,
#                     "def": 29
#                 },
#                 "ppda_allowed": {
#                     "att": 308,
#                     "def": 23
#                 },
#                 "pts": 0,
#                 "result": "l",
#                 "scored": 0,
#                 "wins": 0,
#                 "xG": 1.06219,
#                 "xGA": 0.877996,
#                 "xpts": 1.4662000000000002
#             },
#             {
#                 "date": "2019-01-06 17:30:00",
#                 "deep": 5,
#                 "deep_allowed": 9,
#                 "draws": 0,
#                 "h_a": "a",
#                 "loses": 0,
#                 "missed": 0,
#                 "npxG": 1.54996,
#                 "npxGA": 2.2027,
#                 "npxGD": -0.6527400000000001,
#                 "ppda": {
#                     "att": 349,
#                     "def": 15
#                 },
#                 "ppda_allowed": {
#                     "att": 287,
#                     "def": 32
#                 },
#                 "pts": 3,
#                 "result": "w",
#                 "scored": 2,
#                 "wins": 1,
#                 "xG": 2.29324,
#                 "xGA": 2.2027,
#                 "xpts": 1.4693
#             },
#             {
#                 "date": "2019-01-14 20:00:00",
#                 "deep": 1,
#                 "deep_allowed": 5,
#                 "draws": 0,
#                 "h_a": "h",
#                 "loses": 0,
#                 "missed": 2,
#                 "npxG": 1.93991,
#                 "npxGA": 2.4151,
#                 "npxGD": -0.4751899999999998,
#                 "ppda": {
#                     "att": 242,
#                     "def": 26
#                 },
#                 "ppda_allowed": {
#                     "att": 183,
#                     "def": 34
#                 },
#                 "pts": 3,
#                 "result": "w",
#                 "scored": 3,
#                 "wins": 1,
#                 "xG": 2.68319,
#                 "xGA": 2.4151,
#                 "xpts": 1.5943
#             },
#             {
#                 "date": "2019-01-20 17:30:00",
#                 "deep": 13,
#                 "deep_allowed": 2,
#                 "draws": 1,
#                 "h_a": "a",
#                 "loses": 0,
#                 "missed": 2,
#                 "npxG": 1.82818,
#                 "npxGA": 0.768424,
#                 "npxGD": 1.059756,
#                 "ppda": {
#                     "att": 159,
#                     "def": 31
#                 },
#                 "ppda_allowed": {
#                     "att": 330,
#                     "def": 23
#                 },
#                 "pts": 1,
#                 "result": "d",
#                 "scored": 2,
#                 "wins": 0,
#                 "xG": 1.82818,
#                 "xGA": 0.768424,
#                 "xpts": 2.2204
#             },
#             {
#                 "date": "2019-01-27 17:30:00",
#                 "deep": 5,
#                 "deep_allowed": 3,
#                 "draws": 1,
#                 "h_a": "h",
#                 "loses": 0,
#                 "missed": 0,
#                 "npxG": 0.307366,
#                 "npxGA": 0.549205,
#                 "npxGD": -0.24183900000000008,
#                 "ppda": {
#                     "att": 125,
#                     "def": 27
#                 },
#                 "ppda_allowed": {
#                     "att": 367,
#                     "def": 26
#                 },
#                 "pts": 1,
#                 "result": "d",
#                 "scored": 0,
#                 "wins": 0,
#                 "xG": 0.307366,
#                 "xGA": 0.549205,
#                 "xpts": 0.9639
#             },
#             {
#                 "date": "2019-02-02 15:15:00",
#                 "deep": 4,
#                 "deep_allowed": 6,
#                 "draws": 0,
#                 "h_a": "h",
#                 "loses": 0,
#                 "missed": 1,
#                 "npxG": 1.63134,
#                 "npxGA": 0.30001,
#                 "npxGD": 1.33133,
#                 "ppda": {
#                     "att": 222,
#                     "def": 21
#                 },
#                 "ppda_allowed": {
#                     "att": 213,
#                     "def": 32
#                 },
#                 "pts": 3,
#                 "result": "w",
#                 "scored": 2,
#                 "wins": 1,
#                 "xG": 1.63134,
#                 "xGA": 1.22419,
#                 "xpts": 1.7692999999999999
#             },
#             {
#                 "date": "2019-02-10 15:15:00",
#                 "deep": 3,
#                 "deep_allowed": 4,
#                 "draws": 1,
#                 "h_a": "a",
#                 "loses": 0,
# ...
#             {
#                 "date": "2019-01-12 12:00:00",
#                 "deep": 6,
#                 "deep_allowed": 3,
#                 "draws": 0,
#                 "h_a": "a",
#                 "loses": 1,
#                 "missed": 1,
#                 "npxG": 0.440876,
#                 "npxGA": 1.94908,
#                 "npxGD": -1.5082039999999999,
#                 "ppda": {
#                     "att": 215,
#                     "def": 17
#                 },
#                 "ppda_allowed": {
#                     "att": 226,
#                     "def": 26
#                 },
#                 "pts": 0,
#                 "result": "l",
#                 "scored": 0,
#                 "wins": 0,
#                 "xG": 0.440876,
#                 "xGA": 1.94908,
#                 "xpts": 0.29069999999999996
#             },
#             {
#                 "date": "2019-01-19 17:30:00",
#                 "deep": 2,
#                 "deep_allowed": 10,
#                 "draws": 0,
#                 "h_a": "h",
#                 "loses": 1,
#                 "missed": 3,
#                 "npxG": 1.23016,
#                 "npxGA": 2.74037,
#                 "npxGD": -1.51021,
#                 "ppda": {
#                     "att": 163,
#                     "def": 30
#                 },
#                 "ppda_allowed": {
#                     "att": 188,
#                     "def": 25
#                 },
#                 "pts": 0,
#                 "result": "l",
#                 "scored": 0,
#                 "wins": 0,
#                 "xG": 1.23016,
#                 "xGA": 2.74037,
#                 "xpts": 0.45690000000000003
#             },
#             {
#                 "date": "2019-01-27 17:30:00",
#                 "deep": 3,
#                 "deep_allowed": 5,
#                 "draws": 1,
#                 "h_a": "a",
#                 "loses": 0,
#                 "missed": 0,
#                 "npxG": 0.549205,
#                 "npxGA": 0.307366,
#                 "npxGD": 0.24183900000000008,
#                 "ppda": {
#                     "att": 367,
#                     "def": 26
#                 },
#                 "ppda_allowed": {
#                     "att": 125,
#                     "def": 27
#                 },
#                 "pts": 1,
#                 "result": "d",
#                 "scored": 0,
#                 "wins": 0,
#                 "xG": 0.549205,
#                 "xGA": 0.307366,
#                 "xpts": 1.5504
#             },
#             {
#                 "date": "2019-02-01 20:00:00",
#                 "deep": 4,
#                 "deep_allowed": 2,
#                 "draws": 0,
#                 "h_a": "h",
#                 "loses": 0,
#                 "missed": 0,
#                 "npxG": 1.97934,
#                 "npxGA": 0.546436,
#                 "npxGD": 1.4329040000000002,
#                 "ppda": {
#                     "att": 216,
#                     "def": 25
#                 },
#                 "ppda_allowed": {
#                     "att": 151,
#                     "def": 20
#                 },
#                 "pts": 3,
#                 "result": "w",
#                 "scored": 4,
#                 "wins": 1,
#                 "xG": 1.97934,
#                 "xGA": 0.546436,
#                 "xpts": 2.4699
#             },
#             {
#                 "date": "2019-02-09 19:45:00",
#                 "deep": 1,
#                 "deep_allowed": 8,
#                 "draws": 0,
#                 "h_a": "a",
#                 "loses": 0,
#                 "missed": 0,
#                 "npxG": 0.683864,
#                 "npxGA": 1.37725,
#                 "npxGD": -0.6933860000000001,
#                 "ppda": {
#                     "att": 314,
#                     "def": 28
#                 },
#                 "ppda_allowed": {
#                     "att": 138,
#                     "def": 25
#                 },
#                 "pts": 3,
#                 "result": "w",
#                 "scored": 2,
#                 "wins": 1,
#                 "xG": 0.683864,
#                 "xGA": 1.37725,
#                 "xpts": 0.7069000000000001
#             },
#             {
#                 "date": "2019-02-18 20:00:00",
#                 "deep": 5,
#                 "deep_allowed": 5,
#                 "draws": 0,
#                 "h_a": "h",
#                 "loses": 1,
#                 "missed": 1,
#                 "npxG": 1.16274,
#                 "npxGA": 0.626246,
#                 "npxGD": 0.5364940000000001,
#                 "ppda": {
#                     "att": 200,
#                     "def": 22
#                 },
#                 "ppda_allowed": {
#                     "att": 202,
#                     "def": 27
#                 },
#                 "pts": 0,
#                 "result": "l",
#                 "scored": 0,
#                 "wins": 0,
#                 "xG": 1.16274,
#                 "xGA": 1.36952,
#                 "xpts": 1.1448
#             },
#             {
#                 "date": "2019-02-22 20:00:00",
#                 "deep": 3,
#                 "deep_allowed": 7,
#                 "draws": 1,
#                 "h_a": "a",
#                 "loses": 0,
#                 "missed": 1,
#                 "npxG": 0.983427,
#                 "npxGA": 1.02096,
#                 "npxGD": -0.03753300000000004,
#                 "ppda": {
#                     "att": 321,
#                     "def": 24
#                 },
#                 "ppda_allowed": {
#                     "att": 125,
#                     "def": 22
#                 },
#                 "pts": 1,
#                 "result": "d",
#                 "scored": 1,
#                 "wins": 0,
#                 "xG": 0.983427,
#                 "xGA": 1.02096,
#                 "xpts": 1.3084
#             },
#             {
#                 "date": "2019-03-02 17:30:00",
#                 "deep": 4,
#                 "deep_allowed": 10,
#                 "draws": 0,
#                 "h_a": "h",
#                 "loses": 0,
#                 "missed": 1,
#                 "npxG": 0.940056,
#                 "npxGA": 1.78648,
#                 "npxGD": -0.8464240000000001,
#                 "ppda": {
#                     "att": 338,
#                     "def": 28
#                 },
#                 "ppda_allowed": {
#                     "att": 84,
#                     "def": 31
#                 },
#                 "pts": 3,
#                 "result": "w",
#                 "scored": 2,
#                 "wins": 1,
#                 "xG": 0.940056,
#                 "xGA": 2.52975,
#                 "xpts": 0.28759999999999997
#             },
#             {
#                 "date": "2019-03-09 19:45:00",
#                 "deep": 1,
#                 "deep_allowed": 5,
#                 "draws": 0,
#                 "h_a": "a",
#                 "loses": 1,
#                 "missed": 2,
#                 "npxG": 0.930257,
#                 "npxGA": 0.578165,
#                 "npxGD": 0.35209199999999996,
#                 "ppda": {
#                     "att": 136,
#                     "def": 25
#                 },
#                 "ppda_allowed": {
#                     "att": 118,
#                     "def": 27
#                 },
#                 "pts": 0,
#                 "result": "l",
#                 "scored": 1,
#                 "wins": 0,
#                 "xG": 0.930257,
#                 "xGA": 1.32144,
#                 "xpts": 0.9542999999999999
#             },
#             {
#                 "date": "2019-03-16 12:00:00",
#                 "deep": 4,
#                 "deep_allowed": 6,
#                 "draws": 0,
#                 "h_a": "h",
#                 "loses": 1,
#                 "missed": 3,
#                 "npxG": 1.14681,
#                 "npxGA": 1.4197,
#                 "npxGD": -0.27288999999999985,
#                 "ppda": {
#                     "att": 141,
#                     "def": 25
#                 },
#                 "ppda_allowed": {
#                     "att": 188,
#                     "def": 32
#                 },
#                 "pts": 0,
#                 "result": "l",
#                 "scored": 1,
#                 "wins": 0,
#                 "xG": 1.89009,
#                 "xGA": 2.16298,
#                 "xpts": 1.1469
#             },
#             {
#                 "date": "2019-03-31 18:45:00",
#                 "deep": 6,
#                 "deep_allowed": 17,
#                 "draws": 0,
#                 "h_a": "a",
#                 "loses": 1,
#                 "missed": 3,
#                 "npxG": 1.37203,
#                 "npxGA": 4.62852,
#                 "npxGD": -3.25649,
#                 "ppda": {
#                     "att": 390,
#                     "def": 26
#                 },
#                 "ppda_allowed": {
#                     "att": 150,
#                     "def": 16
#                 },
#                 "pts": 0,
#                 "result": "l",
#                 "scored": 2,
#                 "wins": 0,
#                 "xG": 1.37203,
#                 "xGA": 4.62852,
#                 "xpts": 0.0755
#             },
#             {
#                 "date": "2019-04-03 19:30:00",
#                 "deep": 7,
#                 "deep_allowed": 5,
#                 "draws": 1,
#                 "h_a": "h",
#                 "loses": 0,
#                 "missed": 3,
#                 "npxG": 3.48876,
#                 "npxGA": 1.96582,
#                 "npxGD": 1.5229400000000002,
#                 "ppda": {
#                     "att": 176,
#                     "def": 24
#                 },
#                 "ppda_allowed": {
#                     "att": 170,
#                     "def": 21
#                 },
#                 "pts": 1,
#                 "result": "d",
#                 "scored": 3,
#                 "wins": 0,
#                 "xG": 3.48876,
#                 "xGA": 1.96582,
#                 "xpts": 2.2959
#             },
#             {
#                 "date": "2019-04-07 17:30:00",
#                 "deep": 5,
#                 "deep_allowed": 10,
#                 "draws": 1,
#                 "h_a": "a",
#                 "loses": 0,
#                 "missed": 2,
#                 "npxG": 1.76678,
#                 "npxGA": 1.86334,
#                 "npxGD": -0.09655999999999998,
#                 "ppda": {
#                     "att": 164,
#                     "def": 18
#                 },
#                 "ppda_allowed": {
#                     "att": 135,
#                     "def": 32
#                 },
#                 "pts": 1,
#                 "result": "d",
#                 "scored": 2,
#                 "wins": 0,
#                 "xG": 1.76678,
#                 "xGA": 2.60648,
#                 "xpts": 0.7737
#             },
#             {
#                 "date": "2019-04-13 15:15:00",
#                 "deep": 1,
#                 "deep_allowed": 6,
#                 "draws": 1,
#                 "h_a": "h",
#                 "loses": 0,
#                 "missed": 0,
#                 "npxG": 0.21138,
#                 "npxGA": 0.962057,
#                 "npxGD": -0.750677,
#                 "ppda": {
#                     "att": 416,
#                     "def": 37
#                 },
#                 "ppda_allowed": {
#                     "att": 89,
#                     "def": 27
#                 },
#                 "pts": 1,
#                 "result": "d",
#                 "scored": 0,
#                 "wins": 0,
#                 "xG": 0.21138,
#                 "xGA": 0.962057,
#                 "xpts": 0.5562
#             },
#             {
#                 "date": "2019-04-20 17:30:00",
#                 "deep": 7,
#                 "deep_allowed": 4,
#                 "draws": 1,
#                 "h_a": "a",
#                 "loses": 0,
#                 "missed": 0,
#                 "npxG": 1.04463,
#                 "npxGA": 1.31996,
#                 "npxGD": -0.2753300000000001,
#                 "ppda": {
#                     "att": 187,
#                     "def": 33
#                 },
#                 "ppda_allowed": {
#                     "att": 87,
#                     "def": 21
#                 },
#                 "pts": 1,
#                 "result": "d",
#                 "scored": 0,
#                 "wins": 0,
#                 "xG": 1.04463,
#                 "xGA": 1.31996,
#                 "xpts": 1.1113
#             },
#             {
#                 "date": "2019-04-23 18:30:00",
#                 "deep": 4,
#                 "deep_allowed": 4,
#                 "draws": 0,
#                 "h_a": "h",
#                 "loses": 0,
#                 "missed": 0,
#                 "npxG": 1.19385,
#                 "npxGA": 0.651098,
#                 "npxGD": 0.5427520000000001,
#                 "ppda": {
#                     "att": 137,
#                     "def": 18
#                 },
#                 "ppda_allowed": {
#                     "att": 138,
#                     "def": 29
#                 },
#                 "pts": 3,
#                 "result": "w",
#                 "scored": 2,
#                 "wins": 1,
#                 "xG": 1.19385,
#                 "xGA": 0.651098,
#                 "xpts": 1.8457999999999999
#             },
#             {
#                 "date": "2019-04-28 17:30:00",
#                 "deep": 1,
#                 "deep_allowed": 8,
#                 "draws": 1,
#                 "h_a": "a",
#                 "loses": 0,
#                 "missed": 1,
#                 "npxG": 1.33098,
#                 "npxGA": 1.15808,
#                 "npxGD": 0.17290000000000005,
#                 "ppda": {
#                     "att": 186,
#                     "def": 33
#                 },
#                 "ppda_allowed": {
#                     "att": 243,
#                     "def": 29
#                 },
#                 "pts": 1,
#                 "result": "d",
#                 "scored": 1,
#                 "wins": 0,
#                 "xG": 1.33098,
#                 "xGA": 1.15808,
#                 "xpts": 1.5257
#             },
#             {
#                 "date": "2019-05-05 19:45:00",
#                 "deep": 5,
#                 "deep_allowed": 8,
#                 "draws": 0,
#                 "h_a": "h",
#                 "loses": 1,
#                 "missed": 6,
#                 "npxG": 1.67455,
#                 "npxGA": 2.60868,
#                 "npxGD": -0.9341300000000001,
#                 "ppda": {
#                     "att": 280,
#                     "def": 22
#                 },
#                 "ppda_allowed": {
#                     "att": 230,
#                     "def": 9
#                 },
#                 "pts": 0,
#                 "result": "l",
#                 "scored": 2,
#                 "wins": 0,
#                 "xG": 2.41782,
#                 "xGA": 2.60868,
#                 "xpts": 1.2013
#             },
#             {
#                 "date": "2019-05-12 17:30:00",
#                 "deep": 1,
#                 "deep_allowed": 10,
#                 "draws": 0,
#                 "h_a": "a",
#                 "loses": 1,
#                 "missed": 2,
#                 "npxG": 0.774535,
#                 "npxGA": 2.00914,
#                 "npxGD": -1.234605,
#                 "ppda": {
#                     "att": 247,
#                     "def": 23
#                 },
#                 "ppda_allowed": {
#                     "att": 172,
#                     "def": 20
#                 },
#                 "pts": 0,
#                 "result": "l",
#                 "scored": 1,
#                 "wins": 0,
#                 "xG": 1.51781,
#                 "xGA": 2.00914,
#                 "xpts": 0.9755999999999999
#             },
#             {
#                 "date": "2019-05-18 18:45:00",
#                 "deep": 3,
#                 "deep_allowed": 3,
#                 "draws": 0,
#                 "h_a": "h",
#                 "loses": 0,
#                 "missed": 1,
#                 "npxG": 1.30468,
#                 "npxGA": 0.916693,
#                 "npxGD": 0.3879870000000001,
#                 "ppda": {
#                     "att": 181,
#                     "def": 25
#                 },
#                 "ppda_allowed": {
#                     "att": 221,
#                     "def": 31
#                 },
#                 "pts": 3,
#                 "result": "w",
#                 "scored": 2,
#                 "wins": 1,
#                 "xG": 1.30468,
#                 "xGA": 0.916693,
#                 "xpts": 1.6737
#             }
#         ],
#         "id": "232",
#         "title": "SD Huesca"
#     }
# }

# %%
# Get teams and their relevant ids and put them into separate dictionary
teams = {}
for id in data.keys():
  teams[id] = data[id]['title']

# %%
# EDA to get a feeling of how the JSON is structured
# Column names are all the same, so we just use first element
columns = []
# Check the sample of values per each column
values = []
for id in data.keys():
  columns = list(data[id]['history'][0].keys())
  values = list(data[id]['history'][0].values())
  break

print(columns)
print(values)
# Out:
# ['h_a', 'xG', 'xGA', 'npxG', 'npxGA', 'ppda', 'ppda_allowed', 'deep', 'deep_allowed', 'scored', 'missed', 'xpts', 'result', 'date', 'wins', 'draws', 'loses', 'pts', 'npxGD']
# ['a', 3.34997, 2.39239, 3.34997, 1.64976, {'att': 252, 'def': 19}, {'att': 263, 'def': 20}, 12, 5, 4, 1, 1.9829999999999999, 'w', '2018-08-19 21:15:00', 1, 0, 0, 3, 1.70021]

# %%
sevilla_data = []
for row in data['138']['history']:
  sevilla_data.append(list(row.values()))
  
df = pd.DataFrame(sevilla_data, columns=columns)
df.head(2)
# Out:
#   h_a       xG       xGA     npxG     npxGA                     ppda  \
# 0   a  3.34997  2.392390  3.34997  1.649760  {'att': 252, 'def': 19}
# 1   h  1.97161  0.671429  1.97161  0.671429  {'att': 262, 'def': 16}
#
#               ppda_allowed  deep  deep_allowed  scored  missed    xpts result  \
# 0  {'att': 263, 'def': 20}    12             5       4       1  1.9830      w
# 1  {'att': 237, 'def': 26}    11             3       0       0  2.3331      d
#
#                   date  wins  draws  loses  pts     npxGD
# 0  2018-08-19 21:15:00     1      0      0    3  1.700210
# 1  2018-08-26 21:15:00     0      1      0    1  1.300181

# %%
# Getting data for all teams
dataframes = {}
for id, team in teams.items():
  teams_data = []
  for row in data[id]['history']:
    teams_data.append(list(row.values()))
    
  df = pd.DataFrame(teams_data, columns=columns)
  dataframes[team] = df
  print('Added data for {}.'.format(team))
# Out:
# Added data for Sevilla.
# Added data for Real Sociedad.
# Added data for Espanyol.
# Added data for Getafe.
# Added data for Atletico Madrid.
# Added data for Rayo Vallecano.
# Added data for Valencia.
# Added data for Athletic Club.
# Added data for Barcelona.
# Added data for Real Madrid.
# Added data for Levante.
# Added data for Celta Vigo.
# Added data for Real Betis.
# Added data for Villarreal.
# Added data for Eibar.
# Added data for Alaves.
# Added data for Leganes.
# Added data for Girona.
# Added data for Real Valladolid.
# Added data for SD Huesca.

# %%
# Sample check of our newly created DataFrame
dataframes['Barcelona'].head(2)
# Out:
#   h_a       xG       xGA     npxG     npxGA                     ppda  \
# 0   h  3.26753  0.248353  3.26753  0.248353  {'att': 118, 'def': 17}
# 1   a  1.20392  0.510742  1.20392  0.510742  {'att': 163, 'def': 16}
#
#               ppda_allowed  deep  deep_allowed  scored  missed    xpts result  \
# 0  {'att': 407, 'def': 13}    20             0       3       0  2.9009      w
# 1  {'att': 316, 'def': 15}    15             4       1       0  1.9865      w
#
#                   date  wins  draws  loses  pts     npxGD
# 0  2018-08-18 23:15:00     1      0      0    3  3.019177
# 1  2018-08-25 23:15:00     1      0      0    3  0.693178

# %%
for team, df in dataframes.items():
  dataframes[team]['ppda_coef'] = dataframes[team]['ppda'].apply(lambda x: x['att']/x['def'] if x['def'] != 0 else 0)
  dataframes[team]['oppda_coef'] = dataframes[team]['ppda_allowed'].apply(lambda x: x['att']/x['def'] if x['def'] != 0 else 0)
  
# And check how our new dataframes look based on Sevilla dataframe
dataframes['Sevilla'].head(2)
# Out:
#   h_a       xG       xGA     npxG     npxGA                     ppda  \
# 0   a  3.34997  2.392390  3.34997  1.649760  {'att': 252, 'def': 19}
# 1   h  1.97161  0.671429  1.97161  0.671429  {'att': 262, 'def': 16}
#
#               ppda_allowed  deep  deep_allowed  scored  ...    xpts  result  \
# 0  {'att': 263, 'def': 20}    12             5       4  ...  1.9830       w
# 1  {'att': 237, 'def': 26}    11             3       0  ...  2.3331       d
#
#                   date wins  draws  loses  pts     npxGD  ppda_coef  \
# 0  2018-08-19 21:15:00    1      0      0    3  1.700210  13.263158
# 1  2018-08-26 21:15:00    0      1      0    1  1.300181  16.375000
#
#    oppda_coef
# 0   13.150000
# 1    9.115385
#
# [2 rows x 21 columns]

# %%
cols_to_sum = ['xG', 'xGA', 'npxG', 'npxGA', 'deep', 'deep_allowed', 'scored', 'missed', 'xpts', 'wins', 'draws', 'loses', 'pts', 'npxGD']
cols_to_mean = ['ppda_coef', 'oppda_coef']

# %%
frames = []
for team, df in dataframes.items():
  sum_data = pd.DataFrame(df[cols_to_sum].sum()).transpose()
  mean_data = pd.DataFrame(df[cols_to_mean].mean()).transpose()
  final_df = sum_data.join(mean_data)
  final_df['team'] = team
  final_df['matches'] = len(df)
  frames.append(final_df)
  
full_stat = pd.concat(frames)

# %%
full_stat = full_stat[['team', 'matches', 'wins', 'draws', 'loses', 'scored', 'missed', 'pts', 'xG', 'npxG', 'xGA', 'npxGA', 'npxGD', 'ppda_coef', 'oppda_coef', 'deep', 'deep_allowed', 'xpts']]
full_stat.sort_values('pts', ascending=False, inplace=True)
full_stat.reset_index(inplace=True, drop=True)
full_stat['position'] = range(1,len(full_stat)+1)

# %%
full_stat['xG_diff'] = full_stat['xG'] - full_stat['scored']
full_stat['xGA_diff'] = full_stat['xGA'] - full_stat['missed']
full_stat['xpts_diff'] = full_stat['xpts'] - full_stat['pts']

# %%
cols_to_int = ['wins', 'draws', 'loses', 'scored', 'missed', 'pts', 'deep', 'deep_allowed']
full_stat[cols_to_int] = full_stat[cols_to_int].astype(int)

# %%
 col_order = ['position','team', 'matches', 'wins', 'draws', 'loses', 'scored', 'missed', 'pts', 'xG', 'xG_diff', 'npxG', 'xGA', 'xGA_diff', 'npxGA', 'npxGD', 'ppda_coef', 'oppda_coef', 'deep', 'deep_allowed', 'xpts', 'xpts_diff']
full_stat = full_stat[col_order]
pd.options.display.float_format = '{:,.2f}'.format
full_stat.head(10)
# Out:
#    position             team  matches  wins  draws  loses  scored  missed  \
# 0         1        Barcelona       38    26      9      3      90      36
# 1         2  Atletico Madrid       38    22     10      6      55      29
# 2         3      Real Madrid       38    21      5     12      63      46
# 3         4         Valencia       38    15     16      7      51      35
# 4         5          Sevilla       38    17      8     13      62      47
# 5         6           Getafe       38    15     14      9      48      35
# 6         7         Espanyol       38    14     11     13      48      50
# 7         8    Athletic Club       38    13     14     11      41      45
# 8         9    Real Sociedad       38    13     11     14      45      46
# 9        10           Alaves       38    13     11     14      39      50
#
#    pts    xG  ...   xGA  xGA_diff  npxGA  npxGD  ppda_coef  oppda_coef  deep  \
# 0   87 83.28  ... 44.93      8.93  43.44  33.14       9.02       16.40   417
# 1   76 51.87  ... 41.43     12.43  37.72  11.01      11.07       11.10   252
# 2   68 68.65  ... 48.68      2.68  42.73  19.24       8.90       14.78   341
# 3   61 61.88  ... 42.85      7.85  36.91  19.66      12.96        9.47   278
# 4   59 69.16  ... 46.71     -0.29  41.51  23.03      10.65       10.02   321
# 5   59 47.03  ... 44.23      9.23  39.02   3.56       8.77        5.70   186
# 6   53 50.16  ... 54.62      4.62  48.55  -1.36       9.86        9.82   241
# 7   53 44.44  ... 47.16      2.16  43.44  -4.53       8.30       11.30   221
# 8   50 47.99  ... 48.09      2.09  45.68  -5.13       9.94        9.49   194
# 9   50 40.87  ... 54.53      4.53  50.07 -11.43      11.23        7.10   129
#
#    deep_allowed  xpts  xpts_diff
# 0           171 73.96     -13.04
# 1           190 59.43     -16.57
# 2           168 64.77      -3.23
# 3           215 65.16       4.16
# 4           211 65.08       6.08
# 5           196 53.19      -5.81
# 6           241 50.09      -2.91
# 7           185 50.01      -2.99
# 8           208 51.13       1.13
# 9           270 44.02      -5.98
#
# [10 rows x 22 columns]

# %%
season_data = dict()
season_data[seasons[4]] = full_stat
print(season_data)
full_data = dict()
full_data[leagues[0]] = season_data
print(full_data)
# Out:
# {'2018':     position             team  matches  wins  draws  loses  scored  missed  \
# 0          1        Barcelona       38    26      9      3      90      36
# 1          2  Atletico Madrid       38    22     10      6      55      29
# 2          3      Real Madrid       38    21      5     12      63      46
# 3          4         Valencia       38    15     16      7      51      35
# 4          5          Sevilla       38    17      8     13      62      47
# 5          6           Getafe       38    15     14      9      48      35
# 6          7         Espanyol       38    14     11     13      48      50
# 7          8    Athletic Club       38    13     14     11      41      45
# 8          9    Real Sociedad       38    13     11     14      45      46
# 9         10           Alaves       38    13     11     14      39      50
# 10        11       Real Betis       38    14      8     16      44      52
# 11        12            Eibar       38    11     14     13      46      50
# 12        13          Leganes       38    11     12     15      37      43
# 13        14          Levante       38    11     11     16      59      66
# 14        15       Villarreal       38    10     14     14      49      52
# 15        16       Celta Vigo       38    10     11     17      53      62
# 16        17  Real Valladolid       38    10     11     17      32      51
# 17        18           Girona       38     9     10     19      37      53
# 18        19        SD Huesca       38     7     12     19      43      65
# 19        20   Rayo Vallecano       38     8      8     22      41      70
#
#     pts    xG  ...   xGA  xGA_diff  npxGA  npxGD  ppda_coef  oppda_coef  deep  \
# 0    87 83.28  ... 44.93      8.93  43.44  33.14       9.02       16.40   417
# 1    76 51.87  ... 41.43     12.43  37.72  11.01      11.07       11.10   252
# 2    68 68.65  ... 48.68      2.68  42.73  19.24       8.90       14.78   341
# 3    61 61.88  ... 42.85      7.85  36.91  19.66      12.96        9.47   278
# 4    59 69.16  ... 46.71     -0.29  41.51  23.03      10.65       10.02   321
# 5    59 47.03  ... 44.23      9.23  39.02   3.56       8.77        5.70   186
# 6    53 50.16  ... 54.62      4.62  48.55  -1.36       9.86        9.82   241
# 7    53 44.44  ... 47.16      2.16  43.44  -4.53       8.30       11.30   221
# 8    50 47.99  ... 48.09      2.09  45.68  -5.13       9.94        9.49   194
# 9    50 40.87  ... 54.53      4.53  50.07 -11.43      11.23        7.10   129
# 10   50 51.68  ... 53.54      1.54  49.83  -3.48       9.32       12.38   241
# 11   47 56.63  ... 47.88     -2.12  44.91   5.78       7.07       11.22   235
# 12   45 41.25  ... 43.94      0.94  40.80  -3.26      12.47        9.96   155
# 13   44 54.09  ... 78.86     12.86  72.01 -23.13      10.58        7.04   206
# 14   44 54.80  ... 56.12      4.12  52.40  -2.08      11.15       11.17   232
# 15   41 48.70  ... 63.43      1.43  58.23 -14.73      10.77       11.76   195
# 16   41 41.64  ... 57.65      6.65  50.83 -14.39      11.45        9.83   139
# 17   37 42.99  ... 55.33      2.33  49.39 -10.86      11.39        9.86   177
# 18   33 51.38  ... 63.43     -1.57  56.74 -10.56      10.22        8.70   171
# 19   32 47.23  ... 62.32     -7.68  54.00 -10.48       9.53        7.52   133
#
#     deep_allowed  xpts  xpts_diff
# 0            171 73.96     -13.04
# 1            190 59.43     -16.57
# 2            168 64.77      -3.23
# 3            215 65.16       4.16
# 4            211 65.08       6.08
# 5            196 53.19      -5.81
# 6            241 50.09      -2.91
# 7            185 50.01      -2.99
# 8            208 51.13       1.13
# 9            270 44.02      -5.98
# 10           220 52.39       2.39
# 11           177 56.75       9.75
# 12           190 51.15       6.15
# 13           295 40.23      -3.77
# 14           263 52.18       8.18
# 15           248 41.63       0.63
# 16           243 41.80       0.80
# 17           261 45.17       8.17
# 18           259 44.96      11.96
# 19           253 43.02      11.02
#
# [20 rows x 22 columns]}
# {'La_liga': {'2018':     position             team  matches  wins  draws  loses  scored  missed  \
# 0          1        Barcelona       38    26      9      3      90      36
# 1          2  Atletico Madrid       38    22     10      6      55      29
# 2          3      Real Madrid       38    21      5     12      63      46
# 3          4         Valencia       38    15     16      7      51      35
# 4          5          Sevilla       38    17      8     13      62      47
# 5          6           Getafe       38    15     14      9      48      35
# 6          7         Espanyol       38    14     11     13      48      50
# 7          8    Athletic Club       38    13     14     11      41      45
# 8          9    Real Sociedad       38    13     11     14      45      46
# 9         10           Alaves       38    13     11     14      39      50
# 10        11       Real Betis       38    14      8     16      44      52
# 11        12            Eibar       38    11     14     13      46      50
# 12        13          Leganes       38    11     12     15      37      43
# 13        14          Levante       38    11     11     16      59      66
# 14        15       Villarreal       38    10     14     14      49      52
# 15        16       Celta Vigo       38    10     11     17      53      62
# 16        17  Real Valladolid       38    10     11     17      32      51
# 17        18           Girona       38     9     10     19      37      53
# 18        19        SD Huesca       38     7     12     19      43      65
# 19        20   Rayo Vallecano       38     8      8     22      41      70
#
#     pts    xG  ...   xGA  xGA_diff  npxGA  npxGD  ppda_coef  oppda_coef  deep  \
# 0    87 83.28  ... 44.93      8.93  43.44  33.14       9.02       16.40   417
# 1    76 51.87  ... 41.43     12.43  37.72  11.01      11.07       11.10   252
# 2    68 68.65  ... 48.68      2.68  42.73  19.24       8.90       14.78   341
# 3    61 61.88  ... 42.85      7.85  36.91  19.66      12.96        9.47   278
# 4    59 69.16  ... 46.71     -0.29  41.51  23.03      10.65       10.02   321
# 5    59 47.03  ... 44.23      9.23  39.02   3.56       8.77        5.70   186
# 6    53 50.16  ... 54.62      4.62  48.55  -1.36       9.86        9.82   241
# 7    53 44.44  ... 47.16      2.16  43.44  -4.53       8.30       11.30   221
# 8    50 47.99  ... 48.09      2.09  45.68  -5.13       9.94        9.49   194
# 9    50 40.87  ... 54.53      4.53  50.07 -11.43      11.23        7.10   129
# 10   50 51.68  ... 53.54      1.54  49.83  -3.48       9.32       12.38   241
# 11   47 56.63  ... 47.88     -2.12  44.91   5.78       7.07       11.22   235
# 12   45 41.25  ... 43.94      0.94  40.80  -3.26      12.47        9.96   155
# 13   44 54.09  ... 78.86     12.86  72.01 -23.13      10.58        7.04   206
# 14   44 54.80  ... 56.12      4.12  52.40  -2.08      11.15       11.17   232
# 15   41 48.70  ... 63.43      1.43  58.23 -14.73      10.77       11.76   195
# 16   41 41.64  ... 57.65      6.65  50.83 -14.39      11.45        9.83   139
# 17   37 42.99  ... 55.33      2.33  49.39 -10.86      11.39        9.86   177
# 18   33 51.38  ... 63.43     -1.57  56.74 -10.56      10.22        8.70   171
# 19   32 47.23  ... 62.32     -7.68  54.00 -10.48       9.53        7.52   133
#
#     deep_allowed  xpts  xpts_diff
# 0            171 73.96     -13.04
# 1            190 59.43     -16.57
# 2            168 64.77      -3.23
# 3            215 65.16       4.16
# 4            211 65.08       6.08
# 5            196 53.19      -5.81
# 6            241 50.09      -2.91
# 7            185 50.01      -2.99
# 8            208 51.13       1.13
# 9            270 44.02      -5.98
# 10           220 52.39       2.39
# 11           177 56.75       9.75
# 12           190 51.15       6.15
# 13           295 40.23      -3.77
# 14           263 52.18       8.18
# 15           248 41.63       0.63
# 16           243 41.80       0.80
# 17           261 45.17       8.17
# 18           259 44.96      11.96
# 19           253 43.02      11.02
#
# [20 rows x 22 columns]}}

# %%
full_data = dict()
for league in leagues:
  
  season_data = dict()
  for season in seasons:    
    url = base_url+'/'+league+'/'+season
    res = requests.get(url)
    soup = BeautifulSoup(res.content, "lxml")

    # Based on the structure of the webpage, I found that data is in the JSON variable, under <script> tags
    scripts = soup.find_all('script')
    
    string_with_json_obj = ''

    # Find data for teams
    for el in scripts:
        if 'teamsData' in el.text:
          string_with_json_obj = el.text.strip()

    # print(string_with_json_obj)

    # strip unnecessary symbols and get only JSON data
    ind_start = string_with_json_obj.index("('")+2
    ind_end = string_with_json_obj.index("')")
    json_data = string_with_json_obj[ind_start:ind_end]
    json_data = json_data.encode('utf8').decode('unicode_escape')
    
    
    # convert JSON data into Python dictionary
    data = json.loads(json_data)
    
    # Get teams and their relevant ids and put them into separate dictionary
    teams = {}
    for id in data.keys():
      teams[id] = data[id]['title']
      
    # EDA to get a feeling of how the JSON is structured
    # Column names are all the same, so we just use first element
    columns = []
    # Check the sample of values per each column
    values = []
    for id in data.keys():
      columns = list(data[id]['history'][0].keys())
      values = list(data[id]['history'][0].values())
      break
      
    # Getting data for all teams
    dataframes = {}
    for id, team in teams.items():
      teams_data = []
      for row in data[id]['history']:
        teams_data.append(list(row.values()))

      df = pd.DataFrame(teams_data, columns=columns)
      dataframes[team] = df
      # print('Added data for {}.'.format(team))
      
    
    for team, df in dataframes.items():
      dataframes[team]['ppda_coef'] = dataframes[team]['ppda'].apply(lambda x: x['att']/x['def'] if x['def'] != 0 else 0)
      dataframes[team]['oppda_coef'] = dataframes[team]['ppda_allowed'].apply(lambda x: x['att']/x['def'] if x['def'] != 0 else 0)
      
    cols_to_sum = ['xG', 'xGA', 'npxG', 'npxGA', 'deep', 'deep_allowed', 'scored', 'missed', 'xpts', 'wins', 'draws', 'loses', 'pts', 'npxGD']
    cols_to_mean = ['ppda_coef', 'oppda_coef']
    
    frames = []
    for team, df in dataframes.items():
      sum_data = pd.DataFrame(df[cols_to_sum].sum()).transpose()
      mean_data = pd.DataFrame(df[cols_to_mean].mean()).transpose()
      final_df = sum_data.join(mean_data)
      final_df['team'] = team
      final_df['matches'] = len(df)
      frames.append(final_df)

    full_stat = pd.concat(frames)
    
    full_stat = full_stat[['team', 'matches', 'wins', 'draws', 'loses', 'scored', 'missed', 'pts', 'xG', 'npxG', 'xGA', 'npxGA', 'npxGD', 'ppda_coef', 'oppda_coef', 'deep', 'deep_allowed', 'xpts']]
    full_stat.sort_values('pts', ascending=False, inplace=True)
    full_stat.reset_index(inplace=True, drop=True)
    full_stat['position'] = range(1,len(full_stat)+1)
    
    full_stat['xG_diff'] = full_stat['xG'] - full_stat['scored']
    full_stat['xGA_diff'] = full_stat['xGA'] - full_stat['missed']
    full_stat['xpts_diff'] = full_stat['xpts'] - full_stat['pts']
    
    cols_to_int = ['wins', 'draws', 'loses', 'scored', 'missed', 'pts', 'deep', 'deep_allowed']
    full_stat[cols_to_int] = full_stat[cols_to_int].astype(int)
    
    col_order = ['position', 'team', 'matches', 'wins', 'draws', 'loses', 'scored', 'missed', 'pts', 'xG', 'xG_diff', 'npxG', 'xGA', 'xGA_diff', 'npxGA', 'npxGD', 'ppda_coef', 'oppda_coef', 'deep', 'deep_allowed', 'xpts', 'xpts_diff']
    full_stat = full_stat[col_order]
    full_stat = full_stat.set_index('position')
    # print(full_stat.head(20))
    
    season_data[season] = full_stat
  
  df_season = pd.concat(season_data)
  full_data[league] = df_season
  
data = pd.concat(full_data)
data.head()
# Out:
#                                          team  matches  wins  draws  loses  \
#                 position
# Bundesliga 2014 1               Bayern Munich       34    25      4      5
#                 2                   Wolfsburg       34    20      9      5
#                 3         Borussia M.Gladbach       34    19      9      6
#                 4            Bayer Leverkusen       34    17     10      7
#                 5                    Augsburg       34    15      4     15
#
#                           scored  missed  pts    xG  xG_diff  ...   xGA  \
#                 position                                      ...
# Bundesliga 2014 1             80      18   79 66.21   -13.79  ... 21.94
#                 2             72      38   69 58.35   -13.65  ... 38.82
#                 3             53      26   66 51.74    -1.26  ... 36.34
#                 4             62      37   61 49.16   -12.84  ... 34.72
#                 5             43      43   49 43.91     0.91  ... 46.66
#
#                           xGA_diff  npxGA  npxGD  ppda_coef  oppda_coef  deep  \
#                 position
# Bundesliga 2014 1             3.94  20.42  41.24       5.76       25.02   388
#                 2             0.82  36.42  18.90       9.14       10.29   172
#                 3            10.34  33.31  16.16      12.75       12.78   221
#                 4            -2.28  30.17  18.22       5.69        7.35   246
#                 5             3.66  43.63  -5.91       7.63       10.40   134
#
#                           deep_allowed  xpts  xpts_diff
#                 position
# Bundesliga 2014 1                   83 73.61      -5.39
#                 2                  164 59.95      -9.05
#                 3                  198 57.01      -8.99
#                 4                  108 55.34      -5.66
#                 5                  221 45.50      -3.50
#
# [5 rows x 21 columns]

# %%
data.to_csv('understat.com.csv')
